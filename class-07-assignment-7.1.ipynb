# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
dataset=pd.read_excel('/content/drive/MyDrive/Artificial Intelligence /CoLab /Dataset/assignment aiquist 7.1.xlsx',header=None)

# %%
dataset.head()
# Out:
#     0   1
# 0  21  60
# 1  20  55
# 2  22  60
# 3  22  61
# 4  23  65

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
Knreg=KNeighborsRegressor(n_neighbors=3)

# %%
Knreg.fit(dataset[[0]],dataset[[1]])
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
Knreg.predict([[22]])
# Out:
# array([[60.33333333]])

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
dataset=pd.read_csv('Dataset/supershops.csv')

# %%
dataset.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df1=dataset.copy()
df2=dataset.copy()
df3=dataset.copy()
df4=dataset.copy()
df4=dataset.copy()
df5=dataset.copy()

# %%
x=dataset.drop('Profit',axis=1)
y=dataset['Profit']

# %%
x.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
y.head()
# Out:
# 0    192261.83
# 1    191792.06
# 2    191050.39
# 3    182901.99
# 4    166187.94
# Name: Profit, dtype: float64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Marketing Spend  50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Transport        49 non-null     float64
#  3   Area             50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
dataset.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
dataset.Transport.mean()
# Out:
# np.float64(215331.7324489796)

# %%
dataset.Transport.median()
# Out:
# np.float64(214634.81)

# %%
import seaborn as sns

# %%
sns.histplot(dataset.Transport)
# Out:
# <Axes: xlabel='Transport', ylabel='Count'>

# %% [markdown]
# # Fill With mean

# %%
mean=dataset.Transport.mean()
dataset=dataset.fillna(mean)

# %%
dataset.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          0
# Area               0
# Profit             0
# dtype: int64

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()

# %%
df1.Area=LE.fit_transform(dataset[['Area']])

# %%
df1=pd.DataFrame(df1)

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %%
LE.classes_
# Out:
# array(['Ctg', 'Dhaka', 'Rangpur'], dtype=object)

# %%
LE.transform(LE.classes_)
# Out:
# array([0, 1, 2])

# %% [markdown]
# ## Decode encoded ones to get the original values

# %%
decoded_class=LE.inverse_transform(df1.Area)

# %%
decoded_class
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur', 'Dhaka', 'Rangpur', 'Dhaka', 'Ctg',
#        'Rangpur', 'Dhaka', 'Ctg', 'Rangpur', 'Ctg', 'Rangpur', 'Ctg',
#        'Rangpur', 'Dhaka', 'Ctg', 'Dhaka', 'Rangpur', 'Dhaka', 'Ctg',
#        'Dhaka', 'Rangpur', 'Rangpur', 'Dhaka', 'Ctg', 'Rangpur', 'Dhaka',
#        'Rangpur', 'Dhaka', 'Rangpur', 'Dhaka', 'Ctg', 'Rangpur', 'Ctg',
#        'Dhaka', 'Rangpur', 'Ctg', 'Dhaka', 'Ctg', 'Ctg', 'Rangpur', 'Ctg',
#        'Dhaka', 'Ctg', 'Dhaka', 'Rangpur', 'Ctg', 'Dhaka', 'Ctg'],
#       dtype=object)

# %% [markdown]
# # Label Encoding with Label Mapping

# %%
df2.Area.unique()
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
labelsof_mapping={'Dhaka':1,'Ctg':2,'Rangpur':3}

# %%
labelsof_mapping.keys()
# Out:
# dict_keys(['Dhaka', 'Ctg', 'Rangpur'])

# %%
labelsof_mapping.values()
# Out:
# dict_values([1, 2, 3])

# %%
df2.Area = [labelsof_mapping[area] for area in df2.Area]

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     2  191792.06
# 2        153441.51       101145.55  407934.54     3  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     3  166187.94

# %%
df3['Area'] = df3['Area'].replace(labelsof_mapping)

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     2  191792.06
# 2        153441.51       101145.55  407934.54     3  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     3  166187.94

# %% [markdown]
# # One hot encoding

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
pd.get_dummies(df4['Area'],dtype=int)
# Out:
#     Ctg  Dhaka  Rangpur
# 0     0      1        0
# 1     1      0        0
# 2     0      0        1
# 3     0      1        0
# 4     0      0        1
# 5     0      1        0
# 6     1      0        0
# 7     0      0        1
# 8     0      1        0
# 9     1      0        0
# 10    0      0        1
# 11    1      0        0
# 12    0      0        1
# 13    1      0        0
# 14    0      0        1
# 15    0      1        0
# 16    1      0        0
# 17    0      1        0
# 18    0      0        1
# 19    0      1        0
# 20    1      0        0
# 21    0      1        0
# 22    0      0        1
# 23    0      0        1
# 24    0      1        0
# 25    1      0        0
# 26    0      0        1
# 27    0      1        0
# 28    0      0        1
# 29    0      1        0
# 30    0      0        1
# 31    0      1        0
# 32    1      0        0
# 33    0      0        1
# 34    1      0        0
# 35    0      1        0
# 36    0      0        1
# ...

# %%
dummy=pd.get_dummies(df4['Area'],drop_first=True, prefix='Area',prefix_sep='_',dtype=int)

# %%
df4.drop('Area',axis=1,inplace=True)

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06
# 2        153441.51       101145.55  407934.54  191050.39
# 3        144372.41       118671.85  383199.62  182901.99
# 4        142107.34        91391.77  366168.42  166187.94

# %%
encoded_df4=pd.concat([df4,dummy],axis=1)

# %%
encoded_df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Area_Dhaka  \
# 0        114523.61       136897.80  471784.10  192261.83           1
# 1        162597.70       151377.59  443898.53  191792.06           0
# 2        153441.51       101145.55  407934.54  191050.39           0
# 3        144372.41       118671.85  383199.62  182901.99           1
# 4        142107.34        91391.77  366168.42  166187.94           0
#
#    Area_Rangpur
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1

# %% [markdown]
# # Ordinal Encoder

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ordinals=OrdinalEncoder(categories=[['Dhaka','Ctg','Rangpur']])

# %%
ordinals
# Out:
# OrdinalEncoder(categories=[['Dhaka', 'Ctg', 'Rangpur']])

# %%
df5.Area=ordinals.fit_transform(df5[['Area']])

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10   0.0  192261.83
# 1        162597.70       151377.59  443898.53   1.0  191792.06
# 2        153441.51       101145.55  407934.54   2.0  191050.39
# 3        144372.41       118671.85  383199.62   0.0  182901.99
# 4        142107.34        91391.77  366168.42   2.0  166187.94

# %%
df5.tail()
# Out:
#     Marketing Spend  Administration  Transport  Area    Profit
# 45          1000.23       124153.04    1903.93   0.0  64926.08
# 46          1315.46       115816.21  297114.46   2.0  49490.75
# 47             0.00       135426.92       0.00   1.0  42559.73
# 48           542.05        51743.15       0.00   0.0  35673.41
# 49             0.00       116983.80   45173.06   1.0  14681.40
